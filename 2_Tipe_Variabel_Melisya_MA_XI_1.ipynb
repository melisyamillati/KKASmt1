# %% [markdown]
# <a href="https://colab.research.google.com/github/melisyamillati/KKASmt1/blob/main/2_Tipe_Variabel_Melisya_MA_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Melisya Millati Azka
#
# Kelas: XI.1
#
# No. absen: 25

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 = "melisyaazka.2025@gmail.com"

print(email_user_1)
# Out:
# melisyaazka.2025@gmail.com

# %%
sabun_lifebuoy = 15000

print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#Penulisan variabel hanya boleh menggunakan huruf, angka, dan underscore
#Tidak boleh menggunakan spasi
nama siswa = "Afa"


print(nama siswa)
# Out:
#   File "/tmp/ipython-input-3878009423.py", line 3
#     nama siswa = "Afa"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali dengan angka

1_nama_siswa = "Afa"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-1201669175.py", line 3
#     1_nama_siswa = "Afa"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "Afa"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-643402916.py in <cell line: 0>()
#       2 nama_siswa_1 = "Afa"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#Dilarang menggunakan kata kunci di Bahasa Python
prin = "Afa"

print(prin)
# Out:
# Afa

# %%
end = "Naufal"
print(end)
# Out:
# Naufal

# %%
#Deskriptif
_ = "Favian"

print(_)
# Out:
# Favian

# %%
#Tidak boleh pakai kata kunci phyton
#Kalau error, harus diconnect dulu
#print = "Devin"

#print(print)

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# ##Assign ke Banyak Variabel Sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# #Aritmatika

# %%
print(5000*3)
# Out:
# 15000

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operand ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print(banyak_botol_per_kardus * jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = banyak_botol_per_kardus * jumlah_kardus
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "Icha"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang =-1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8

type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10 '

# %%
panjang = input()
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
##Tipe data masih string dan harus diconvert ke integer/float
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4143754353.py in <cell line: 0>()
#       1 ##Tipe data masih string dan harus diconvert ke integer/float
# ----> 2 luas = panjang*lebar
#       3
#       4 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas oersegi panjang adalah 40 cm^2")
# Out:
# Masukkan panjang persegi: 4
# Masukkan lebar persegi: 10
# Luas oersegi panjang adalah 40 cm^2

# %%
jari_jari_tabung = float(input("silahkan masukkan jari jari tabung: "))
tinggi_tabung = float(input("silahkan masukkan tinggi tabung: "))
phi = 3.14

volume_tabung = phi * jari_jari_tabung**2 * tinggi_tabung

print(f"volume tabung adalah {volume_tabung} cm^3")
# Out:
# silahkan masukkan jari jari tabung: 3
# silahkan masukkan tinggi tabung: 13
# volume tabung adalah 367.38 cm^3

# %% [markdown]
# #Operator Perbanding

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 8)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print(1 !=1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print (125 >=iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
bb_min = 55
umur_max = 25
tinggi_farel = 170
bb_farel = 55
umur_farel = 23

print (tinggi_farel >= tinggi_min and bb_farel > bb_min and umur_farel <= umur_max )
# Out:
# False
